# %% [markdown]
# # Tutorial 7. Web Crawling
# - **GOAL**: scrapping news data from Naver News Sports
# - url: https://sports.news.naver.com/wfootball/news/index?isphoto=N

# %% [markdown]
# ### 0. Chrome Webdriver
# Before starting this tutorial, please prepare [Chrome webdriver](https://chromedriver.chromium.org/downloads) corresponding to your Chrome browser version!
#
# Locate the driver file in the current directory containing this notebook file!
# - Windows: `./chromedriver.exe`
# - MacOS: `./chromedirver`

# %% [markdown]
# ### 1. Open Selenium browser using Chrome webdriver
# This will open a new browser. **Don't close it** until the crawling process is completed!

# %%
from selenium import webdriver

# run the one of the code lines below according to your OS type
driver = webdriver.Chrome('./chromedriver') # mac
# driver = webdriver.Chrome('./chromedriver.exe') # windows

driver.implicitly_wait(3) # waiting 3 seconds

# %%
# access to target url
driver.get('https://sports.news.naver.com/wfootball/news/index?isphoto=N')

# %% [markdown]
# ### 2. Find element(s) by css selector
# - The css selector value can be obtained by Chrome inspection tool (Ctrl + Shift + I).
# 1. Copy the css selector value of the targeting element
# 2. Get the elements (what is the difference between the two code lines below?

# %%
driver.find_element("css selector", "#_newsList > ul > li > div > a > span")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="a1c36ec8-2fd3-47b8-932e-8e4a4eb5a802")>

# %%
driver.find_elements("css selector", "#_newsList > ul > li > div > a > span")
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="a1c36ec8-2fd3-47b8-932e-8e4a4eb5a802")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="71d4183b-7c7a-44f7-b5c7-75930ec9934a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="e958b385-bbb1-4c58-ab1c-97bf484a9999")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="8ea1c553-e3fd-4e3e-b258-220e85de972d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="73bae0b8-80eb-46df-a0a5-2180169a9033")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="b1df44cc-0da0-40f1-965c-e2f8f004f3d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="de165f69-f98b-496f-a7a7-09eb0e2075d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="ba8ece35-187f-427e-9b31-dc7cd27134ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="67de2267-d089-479e-acd4-f696379ff606")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="befdf7b3-df2d-49b0-96fa-670ab9a6ddc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="e162b9fc-98b9-4b24-b74a-b1f3a028331d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="29999063-8b6c-4c77-ace7-552f51ae2413")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="d250f422-272e-409d-9dd1-973258b1e786")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="05876b4b-c855-4b58-84ff-23ae54782210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="5b05923f-50b1-4e7c-a27d-584202a99849")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="cd02dd1a-ca38-4d40-b26e-9dbac246ac97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="a19b0cde-9949-430e-8b5b-95c6beffc854")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="a53850fc-f1c3-4461-b67d-955d3f2361ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="fcfeba50-fc50-4128-9cfc-83bab06a5faa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aac7657c4616d38dbbdc5ea8f45d2990", element="7ed65d86-9c82-4325-9978-00e9fd552e0e")>]

# %% [markdown]
# ### 3. Scrapping data
# 1. Since the news webpage contains multiple news items (css selector value: `#_newsList > ul > li`), we will use `for` loop.
# 2. For each item, we can get attribute values like news title, news page url, or datetime.
# 3. The attribute values will be accumulated in lists.

# %%
# news items (objects)
elements = driver.find_elements("css selector", '#_newsList > ul > li')

# news attribute lists
title_list = []
url_list = []
desc_list = []
img_list = []
pub_list = []
dt_list = []

for x in elements:
    # title
    title = x.find_element("css selector", 'div > a > span').text
    # short description
    desc = x.find_element("css selector", 'div > p').text
    # page url
    url = x.find_element("css selector", 'a').get_attribute("href")
    # image url
    img = x.find_element("css selector", 'a > img').get_attribute("src")
    # publisher
    pub = x.find_element("css selector", 'div > div > span.press').text
    # datetime
    dt = x.find_element("css selector", 'div > div > span.time').text
    # print
    print(title)
    print(desc)
    print(url)
    print(img)
    print(pub, dt)
    print()
    # append news item values to the attribute lists
    title_list.append(title)
    url_list.append(url)
    desc_list.append(desc)
    img_list.append(img)
    pub_list.append(pub)
    dt_list.append(dt)
# Out:
# '유로파 갈 팀이 뭐?' 비웃음 폭발... 슈퍼리그 12팀 중 5팀, 챔스 탈락
# 2022~2023시즌 유럽축구연맹(UEFA) 챔피언스리그 탈락이 확정된 5팀./사진=풋볼조 공식 SNS 갈무리꼴이 우습게 됐다. 최고의 팀, 최고의 선수가 ...
# https://sports.news.naver.com/wfootball/news/read?oid=108&aid=0003100199
# https://imgnews.pstatic.net/image/origin/108/2022/10/27/3100199.jpg?type=w140
# 스타뉴스 2022.10.27 20:04
#
# '황의조, 황인범, 정우영 총출동' 코리안 리거들의 유로파리그 맞대결
# [OSEN=서정환 기자] 코리안 리거들이 꿈의 무대에서 맞대결을 펼친다. SC 프라이부르크(이하 프라이부르크)의 정우영과 올림피아코스의 ‘황-황듀오’ 황의조...
# https://sports.news.naver.com/wfootball/news/read?oid=109&aid=0004728687
# https://imgnews.pstatic.net/image/origin/109/2022/10/27/4728687.jpg?type=w140
# OSEN 2022.10.27 20:03
#
# '공격 너무 답답해'..."토트넘, 창의적인 MF 영입 필요"
# [포포투=이규학]토트넘 훗스퍼에 가장 필요한 포지션은 창의성을 가진 공격형 미드필더다.영국 '풋볼 인사이더'는 27일(한국시간) "안토니오 콘테 감독의 시스...
# https://sports.news.naver.com/wfootball/news/read?oid=411&aid=0000017613
# https://imgnews.pstatic.net/image/origin/411/2022/10/27/17613.jpg?type=w140
# 포포투 2022.10.27 20:01
#
# 전 EPL 심판 , “케인 극장골, 취소되지 말았어야 돼”
# [스포탈코리아] 박주성 기자= 해리 케인의 극장골 취소를 두고 다양한 이야기가 나오고 있다. 토트넘 홋스퍼는 27일 오전 4시(한국 시간) 토트넘 홋스퍼 스...
# https://sports.news.naver.com/wfootball/news/read?oid=139&aid=0002174437
# https://imgnews.pstatic.net/image/origin/139/2022/10/27/2174437.jpg?type=w140
# 스포탈코리아 2022.10.27 19:53
#
# 콘테, UCL 최종전 지휘 불가...'16강 진출 어떡하나'
# 안토니오 콘테 감독이 조별리그 6차전에서 터치라인에 설 수 없다.토트넘 훗스퍼는 27일 오전 4시(한국시간) 영국 런던에 위치한 토트넘 훗스퍼 스타디움에서 ...
# https://sports.news.naver.com/wfootball/news/read?oid=413&aid=0000148983
# https://imgnews.pstatic.net/image/origin/413/2022/10/27/148983.jpg?type=w140
# 인터풋볼 2022.10.27 19:46
#
# 벵거가 말하는 '메날두'의 차이 "호날두는 운동선수, 메시는 예술가"
# <저작권자(c) 연합뉴스, 무단 전재-재배포 금지>[스포츠조선 박찬준 기자]"호날두는 운동선수, 메시는 예술가!"아르센 벵거 전 아스널 감독의 평가였다. 이...
# https://sports.news.naver.com/wfootball/news/read?oid=076&aid=0003932224
# https://imgnews.pstatic.net/image/origin/076/2022/10/27/3932224.jpg?type=w140
# 스포츠조선 2022.10.27 19:42
#
# 토트넘 16강 초비상…콘테 마르세유전 '출입 금지'
# ▲ 안토니오 콘테 토트넘 홋스퍼 감독.[스포티비뉴스=김건일 기자] 잉글랜드 프리미어리그 토트넘 홋스퍼가 안토니오 콘테 감독 없이 UEFA 챔피언스리그 16강...
# https://sports.news.naver.com/wfootball/news/read?oid=477&aid=0000390583
# https://imgnews.pstatic.net/image/origin/477/2022/10/27/390583.jpg?type=w140
# 스포티비뉴스 2022.10.27 19:26
#
# '유로파리그' 코리안 더비?… 정우영 vs '황·황듀오', 출전명단 포함
# SC프라이부르크의 '작은' 정우영과 '황·황 듀오' 황의조와 황인범이 유로파리그에 동시 출격할 지 기대를 모은다. 사진은 오는 28일 유로파리그 조별리그 5...
# https://sports.news.naver.com/wfootball/news/read?oid=417&aid=0000864168
# https://imgnews.pstatic.net/image/origin/417/2022/10/27/864168.jpg?type=w140
# 머니S 2022.10.27 19:24
#
# 랑닉 말 들었다면…”맨유, 홀란-디아스-은쿤쿠 영입 거절”
# [스포탈코리아] 박주성 기자= 랄프 랑닉 감독의 말을 들었다면 어땠을까.독일 언론 ‘빌트’의 크리스티안 폴크 기자는 최근 랄프 랑닉 감독이 맨체스터 유나이티...
# https://sports.news.naver.com/wfootball/news/read?oid=139&aid=0002174436
# https://imgnews.pstatic.net/image/origin/139/2022/10/27/2174436.jpg?type=w140
# 스포탈코리아 2022.10.27 19:22
#
# '제발 이런 것 좀 하지마…' 에메르송, 어이없는 노룩패스→공 헌납
# 사진=BT 스포츠[포포투=김환]에메르송 로얄이 어이없는 노룩패스를 선보였다.토트넘 훗스퍼는 27일 오전 4시(한국시간) 영국 런던에 위치한 토트넘 훗스퍼 스...
# https://sports.news.naver.com/wfootball/news/read?oid=411&aid=0000017611
# https://imgnews.pstatic.net/image/origin/411/2022/10/27/17611.jpg?type=w140
# 포포투 2022.10.27 19:21
#
# “토트넘, 손흥민 팔아야 한다면 해외리그로…PSG, 레알 영입 경쟁”
# [사진] ⓒGettyimages(무단전재 및 재배포 금지)[OSEN=서정환 기자] 손흥민(30, 토트넘)이 빅클럽 이적설이 끊이지 않고 있다.‘포포투 영국판...
# https://sports.news.naver.com/wfootball/news/read?oid=109&aid=0004728579
# https://imgnews.pstatic.net/image/origin/109/2022/10/27/4728579.jpg?type=w140
# OSEN 2022.10.27 19:12
#
# 뉴캐슬, '첼시-레알 관심' 기마랑이스에게 '주급 20만 파운드' 보상
# 뉴캐슬 유나이티드가 '핵심 미드필더' 브루노 기마랑이스에게 재계약을 건넨다.영국 '데일리 메일'은 27일(한국시간) "첼시와 레알 마드리드는 기마랑이스에게 ...
# https://sports.news.naver.com/wfootball/news/read?oid=413&aid=0000148982
# https://imgnews.pstatic.net/image/origin/413/2022/10/27/148982.jpg?type=w140
# 인터풋볼 2022.10.27 19:11
#
# "여름 도박이 절대적 재앙 불러"…UCL 탈락으로 궁지 몰렸다
# (베스트 일레븐)FC 바르셀로나가 지난여름 이적시장에서 거액의 투자를 했으나, UCL에서 탈락하면서 위기를 맞게 됐다.바르셀로나는 27일(한국 시간) 스페인...
# https://sports.news.naver.com/wfootball/news/read?oid=343&aid=0000116716
# https://imgnews.pstatic.net/image/origin/343/2022/10/27/116716.jpg?type=w140
# 베스트일레븐 2022.10.27 19:06
#
# VAR에 분노 폭발한 콘테 향해…스포르팅 감독은 대만족 "공정해"
# ▲ 스포르팅CP전에서 퇴장 당한 안토니오 콘테 토트넘 홋스퍼 감독(왼쪽) ⓒ연합뉴스/AP▲ VAR로 희비가 갈린 토트넘 홋스퍼와 스포르팅CP ⓒ연합뉴스/RE...
# https://sports.news.naver.com/wfootball/news/read?oid=477&aid=0000390569
# https://imgnews.pstatic.net/image/origin/477/2022/10/27/390569.jpg?type=w140
# 스포티비뉴스 2022.10.27 19:01
#
# '뻔뻔(?)한' 호날두..."언제나처럼 헌신할 것"
# (엑스포츠뉴스 나승우 기자) 토트넘전 무단 조기 퇴근으로 물의를 빚었던 맨체스터 유나이티드 공격수 크리스티아누 호날두가 다소 뻔뻔하게 복귀를 선언했다.호날두...
# https://sports.news.naver.com/wfootball/news/read?oid=311&aid=0001517790
# https://imgnews.pstatic.net/image/origin/311/2022/10/27/1517790.jpg?type=w140
# 엑스포츠뉴스 2022.10.27 19:01
#
# 콘테 대폭발 "정말 화가 난다…VAR 판정은 우리에게 큰 피해를 줬다"
# [마이데일리 = 김건호 기자]안토니오 콘테(53, 토트넘) 감독이 VAR 판정에 분노했다.토트넘 홋스퍼는 27일 오전 4시(한국시간) 영국 런던의 토트넘 홋...
# https://sports.news.naver.com/wfootball/news/read?oid=117&aid=0003661777
# https://imgnews.pstatic.net/image/origin/117/2022/10/27/3661777.jpg?type=w140
# 마이데일리 2022.10.27 18:46
#
# ‘2승 2무 11패’ B.뮌헨만 만나면 작아지는 바르셀로나
# [스포탈코리아] 박주성 기자= 바르셀로나가 또 다시 무릎을 꿇었다.바르셀로나는 27일 오전 4시(한국 시간) 스페인 바르셀로나 스포티파이 캄프 누에서 열린 ...
# https://sports.news.naver.com/wfootball/news/read?oid=139&aid=0002174434
# https://imgnews.pstatic.net/image/origin/139/2022/10/27/2174434.jpg?type=w140
# 스포탈코리아 2022.10.27 18:46
#
# 드디어 출전한 토트넘 유망주…팬들은 "다음 경기 선발로 써!"
# 사진=토트넘 훗스퍼 SNS[포포투=김환]토트넘 훗스퍼 팬들이 브리안 힐의 선발 기용을 요구했다.토트넘 훗스퍼는 27일 오전 4시(한국시간) 영국 런던에 위치...
# https://sports.news.naver.com/wfootball/news/read?oid=411&aid=0000017609
# https://imgnews.pstatic.net/image/origin/411/2022/10/27/17609.jpg?type=w140
# 포포투 2022.10.27 18:41
#
# 아르테타 흐뭇...제수스, "50, 60, 70경기 뛸 준비됐다"
# 가브리엘 제수스가 든든한 발언을 했다.아스널은 28일 오전 1시 45분(한국시간) 네덜란드 아인트호벤에 위치한 필립스 스타디움에서 PSV 아인트호벤과 202...
# https://sports.news.naver.com/wfootball/news/read?oid=413&aid=0000148980
# https://imgnews.pstatic.net/image/origin/413/2022/10/27/148980.jpg?type=w140
# 인터풋볼 2022.10.27 18:41
#
# [영상] 너무 잔인한 소녀들의 월드컵…독수리 떼도 지켜본 반전의 승부차기
# 지난 11일부터 인도에서는 국제축구연맹(FIFA) 17세 이하 여자 월드컵이 열리고 있습니다. 27일 현재, 스페인과 콜롬비아가 결승에 올라있는데요. 스페인...
# https://sports.news.naver.com/wfootball/news/read?oid=056&aid=0011364099
# https://imgnews.pstatic.net/image/origin/056/2022/10/27/11364099.jpg?type=w140
# KBS 2022.10.27 18:39

# %% [markdown]
# Here, we still need to scrap the news main body text located on the another webpage.
# - You can get it by iteratively access to `url_list` containing news page url values.
# - The css selector value can be obtained by Chrome inspection tool (Ctrl + Shift + I).

# %%
text_list = [] # main text will be collected

for url in url_list:
    driver.get(url)
    newstext = driver.find_element("css selector", '#newsEndContents').text
    text_list.append(newstext)

# %% [markdown]
# ### 4. Save data in CSV format
# We will use Pandas dataframe.

# %%
import pandas as pd

# dataframe can be made using multiple lists having same length
df = pd.DataFrame({'title': title_list, 
                   'url': url_list, 
                   'short_desc': desc_list, 
                   'text': text_list,
                   'img': img_list, 
                   'publisher': pub_list,
                   'datetime': dt_list,
                  })
df
# Out:
#                                            title  \
# 0   '유로파 갈 팀이 뭐?' 비웃음 폭발... 슈퍼리그 12팀 중 5팀, 챔스 탈락
# 1         '황의조, 황인범, 정우영 총출동' 코리안 리거들의 유로파리그 맞대결
# 2             '공격 너무 답답해'..."토트넘, 창의적인 MF 영입 필요"
# 3               전 EPL 심판 , “케인 극장골, 취소되지 말았어야 돼”
# 4              콘테, UCL 최종전 지휘 불가...'16강 진출 어떡하나'
# 5         벵거가 말하는 '메날두'의 차이 "호날두는 운동선수, 메시는 예술가"
# 6                   토트넘 16강 초비상…콘테 마르세유전 '출입 금지'
# 7       '유로파리그' 코리안 더비?… 정우영 vs '황·황듀오', 출전명단 포함
# 8               랑닉 말 들었다면…”맨유, 홀란-디아스-은쿤쿠 영입 거절”
# 9          '제발 이런 것 좀 하지마…' 에메르송, 어이없는 노룩패스→공 헌납
# 10        “토트넘, 손흥민 팔아야 한다면 해외리그로…PSG, 레알 영입 경쟁”
# 11       뉴캐슬, '첼시-레알 관심' 기마랑이스에게 '주급 20만 파운드' 보상
# 12            "여름 도박이 절대적 재앙 불러"…UCL 탈락으로 궁지 몰렸다
# 13          VAR에 분노 폭발한 콘테 향해…스포르팅 감독은 대만족 "공정해"
# 14                  '뻔뻔(?)한' 호날두..."언제나처럼 헌신할 것"
# 15       콘테 대폭발 "정말 화가 난다…VAR 판정은 우리에게 큰 피해를 줬다"
# 16              ‘2승 2무 11패’ B.뮌헨만 만나면 작아지는 바르셀로나
# 17            드디어 출전한 토트넘 유망주…팬들은 "다음 경기 선발로 써!"
# 18          아르테타 흐뭇...제수스, "50, 60, 70경기 뛸 준비됐다"
# 19      [영상] 너무 잔인한 소녀들의 월드컵…독수리 떼도 지켜본 반전의 승부차기
#
#                                                   url  \
# 0   https://sports.news.naver.com/wfootball/news/r...
# 1   https://sports.news.naver.com/wfootball/news/r...
# 2   https://sports.news.naver.com/wfootball/news/r...
# 3   https://sports.news.naver.com/wfootball/news/r...
# 4   https://sports.news.naver.com/wfootball/news/r...
# 5   https://sports.news.naver.com/wfootball/news/r...
# 6   https://sports.news.naver.com/wfootball/news/r...
# 7   https://sports.news.naver.com/wfootball/news/r...
# 8   https://sports.news.naver.com/wfootball/news/r...
# 9   https://sports.news.naver.com/wfootball/news/r...
# 10  https://sports.news.naver.com/wfootball/news/r...
# 11  https://sports.news.naver.com/wfootball/news/r...
# 12  https://sports.news.naver.com/wfootball/news/r...
# 13  https://sports.news.naver.com/wfootball/news/r...
# 14  https://sports.news.naver.com/wfootball/news/r...
# 15  https://sports.news.naver.com/wfootball/news/r...
# 16  https://sports.news.naver.com/wfootball/news/r...
# 17  https://sports.news.naver.com/wfootball/news/r...
# 18  https://sports.news.naver.com/wfootball/news/r...
# 19  https://sports.news.naver.com/wfootball/news/r...
#
#                                            short_desc  \
# 0   2022~2023시즌 유럽축구연맹(UEFA) 챔피언스리그 탈락이 확정된 5팀./사진...
# 1   [OSEN=서정환 기자] 코리안 리거들이 꿈의 무대에서 맞대결을 펼친다. SC 프라...
# 2   [포포투=이규학]토트넘 훗스퍼에 가장 필요한 포지션은 창의성을 가진 공격형 미드필더...
# 3   [스포탈코리아] 박주성 기자= 해리 케인의 극장골 취소를 두고 다양한 이야기가 나오...
# 4   안토니오 콘테 감독이 조별리그 6차전에서 터치라인에 설 수 없다.토트넘 훗스퍼는 2...
# 5   <저작권자(c) 연합뉴스, 무단 전재-재배포 금지>[스포츠조선 박찬준 기자]"호날두...
# 6   ▲ 안토니오 콘테 토트넘 홋스퍼 감독.[스포티비뉴스=김건일 기자] 잉글랜드 프리미어...
# 7   SC프라이부르크의 '작은' 정우영과 '황·황 듀오' 황의조와 황인범이 유로파리그에 ...
# 8   [스포탈코리아] 박주성 기자= 랄프 랑닉 감독의 말을 들었다면 어땠을까.독일 언론 ...
# 9   사진=BT 스포츠[포포투=김환]에메르송 로얄이 어이없는 노룩패스를 선보였다.토트넘 ...
# 10  [사진] ⓒGettyimages(무단전재 및 재배포 금지)[OSEN=서정환 기자] ...
# 11  뉴캐슬 유나이티드가 '핵심 미드필더' 브루노 기마랑이스에게 재계약을 건넨다.영국 '...
# 12  (베스트 일레븐)FC 바르셀로나가 지난여름 이적시장에서 거액의 투자를 했으나, UC...
# 13  ▲ 스포르팅CP전에서 퇴장 당한 안토니오 콘테 토트넘 홋스퍼 감독(왼쪽) ⓒ연합뉴스...
# 14  (엑스포츠뉴스 나승우 기자) 토트넘전 무단 조기 퇴근으로 물의를 빚었던 맨체스터 유...
# 15  [마이데일리 = 김건호 기자]안토니오 콘테(53, 토트넘) 감독이 VAR 판정에 분...
# 16  [스포탈코리아] 박주성 기자= 바르셀로나가 또 다시 무릎을 꿇었다.바르셀로나는 27...
# 17  사진=토트넘 훗스퍼 SNS[포포투=김환]토트넘 훗스퍼 팬들이 브리안 힐의 선발 기용...
# 18  가브리엘 제수스가 든든한 발언을 했다.아스널은 28일 오전 1시 45분(한국시간) ...
# 19  지난 11일부터 인도에서는 국제축구연맹(FIFA) 17세 이하 여자 월드컵이 열리고...
#
#                                                  text  \
# 0   2022~2023시즌 유럽축구연맹(UEFA) 챔피언스리그 탈락이 확정된 5팀./사진...
# 1   [OSEN=서정환 기자] 코리안 리거들이 꿈의 무대에서 맞대결을 펼친다. \n\nS...
# 2   [포포투=이규학]\n\n토트넘 훗스퍼에 가장 필요한 포지션은 창의성을 가진 공격형 ...
# 3   [스포탈코리아] 박주성 기자= 해리 케인의 극장골 취소를 두고 다양한 이야기가 나오...
# 4   안토니오 콘테 감독이 조별리그 6차전에서 터치라인에 설 수 없다.\n\n토트넘 훗스...
# 5   <저작권자(c) 연합뉴스, 무단 전재-재배포 금지>\n[스포츠조선 박찬준 기자]"호...
# 6   ▲ 안토니오 콘테 토트넘 홋스퍼 감독.\n\n\n[스포티비뉴스=김건일 기자] 잉글랜...
# 7   SC프라이부르크의 '작은' 정우영과 '황·황 듀오' 황의조와 황인범이 유로파리그에 ...
# 8   [스포탈코리아] 박주성 기자= 랄프 랑닉 감독의 말을 들었다면 어땠을까.\n\n독일...
# 9   사진=BT 스포츠\n\n\n[포포투=김환]\n\n에메르송 로얄이 어이없는 노룩패스를...
# 10  [사진] ⓒGettyimages(무단전재 및 재배포 금지)\n\n\n[OSEN=서정...
# 11  뉴캐슬 유나이티드가 '핵심 미드필더' 브루노 기마랑이스에게 재계약을 건넨다.\n\n...
# 12  (베스트 일레븐)\n\nFC 바르셀로나가 지난여름 이적시장에서 거액의 투자를 했으나...
# 13  ▲ 스포르팅CP전에서 퇴장 당한 안토니오 콘테 토트넘 홋스퍼 감독(왼쪽) ⓒ연합뉴스...
# 14  (엑스포츠뉴스 나승우 기자) 토트넘전 무단 조기 퇴근으로 물의를 빚었던 맨체스터 유...
# 15  [마이데일리 = 김건호 기자]안토니오 콘테(53, 토트넘) 감독이 VAR 판정에 분...
# 16  [스포탈코리아] 박주성 기자= 바르셀로나가 또 다시 무릎을 꿇었다.\n\n바르셀로나...
# 17  사진=토트넘 훗스퍼 SNS\n\n\n[포포투=김환]\n\n토트넘 훗스퍼 팬들이 브리...
# 18  가브리엘 제수스가 든든한 발언을 했다.\n\n아스널은 28일 오전 1시 45분(한국...
# 19  지난 11일부터 인도에서는 국제축구연맹(FIFA) 17세 이하 여자 월드컵이 열리고...
#
#                                                   img publisher  \
# 0   https://imgnews.pstatic.net/image/origin/108/2...      스타뉴스
# 1   https://imgnews.pstatic.net/image/origin/109/2...      OSEN
# 2   https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 3   https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 4   https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 5   https://imgnews.pstatic.net/image/origin/076/2...     스포츠조선
# 6   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 7   https://imgnews.pstatic.net/image/origin/417/2...       머니S
# 8   https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 9   https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 10  https://imgnews.pstatic.net/image/origin/109/2...      OSEN
# 11  https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 12  https://imgnews.pstatic.net/image/origin/343/2...    베스트일레븐
# 13  https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 14  https://imgnews.pstatic.net/image/origin/311/2...    엑스포츠뉴스
# 15  https://imgnews.pstatic.net/image/origin/117/2...     마이데일리
# 16  https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 17  https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 18  https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 19  https://imgnews.pstatic.net/image/origin/056/2...       KBS
#
#             datetime
# 0   2022.10.27 20:04
# 1   2022.10.27 20:03
# 2   2022.10.27 20:01
# 3   2022.10.27 19:53
# 4   2022.10.27 19:46
# 5   2022.10.27 19:42
# 6   2022.10.27 19:26
# 7   2022.10.27 19:24
# 8   2022.10.27 19:22
# 9   2022.10.27 19:21
# 10  2022.10.27 19:12
# 11  2022.10.27 19:11
# 12  2022.10.27 19:06
# 13  2022.10.27 19:01
# 14  2022.10.27 19:01
# 15  2022.10.27 18:46
# 16  2022.10.27 18:46
# 17  2022.10.27 18:41
# 18  2022.10.27 18:41
# 19  2022.10.27 18:39

# %% [markdown]
# Save the dataframe into a CSV (comma-separated values) file.
#
# - Here, we will use `\t` (tab) instead of `,` (comma) since the news title or text may contain commas.
# (When we read csv file, we parse each row using comma, i.e., all rows must contain the same number of commas.)

# %%
df.to_csv('news.csv', # filename
          sep='\t', # values separated by tab
          index=False, # exclude index column
          encoding='utf-8') # utf-8 encoding is widely used and makes us comfortable!

# %% [markdown]
# You can load data using `pd.read_csv()`.

# %%
pd.read_csv('news.csv', sep='\t')
# Out:
#                                        title  \
# 0               토트넘 16강 초비상…콘테 마르세유전 '출입 금지'
# 1   '유로파리그' 코리안 더비?… 정우영 vs '황·황듀오', 출전명단 포함
# 2           랑닉 말 들었다면…”맨유, 홀란-디아스-은쿤쿠 영입 거절”
# 3      '제발 이런 것 좀 하지마…' 에메르송, 어이없는 노룩패스→공 헌납
# 4     “토트넘, 손흥민 팔아야 한다면 해외리그로…PSG, 레알 영입 경쟁”
# 5    뉴캐슬, '첼시-레알 관심' 기마랑이스에게 '주급 20만 파운드' 보상
# 6         "여름 도박이 절대적 재앙 불러"…UCL 탈락으로 궁지 몰렸다
# 7       VAR에 분노 폭발한 콘테 향해…스포르팅 감독은 대만족 "공정해"
# 8               '뻔뻔(?)한' 호날두..."언제나처럼 헌신할 것"
# 9    콘테 대폭발 "정말 화가 난다…VAR 판정은 우리에게 큰 피해를 줬다"
# 10          ‘2승 2무 11패’ B.뮌헨만 만나면 작아지는 바르셀로나
# 11        드디어 출전한 토트넘 유망주…팬들은 "다음 경기 선발로 써!"
# 12      아르테타 흐뭇...제수스, "50, 60, 70경기 뛸 준비됐다"
# 13  [영상] 너무 잔인한 소녀들의 월드컵…독수리 떼도 지켜본 반전의 승부차기
# 14              쿨리발리 흔적 지웠다…카펠로 "김민재가 훨씬 잘해"
# 15        엉뚱한 '노룩 패스'에 팬들마저 당황, "제발 토트넘 떠나라"
# 16          한국산 ‘월클’의 희비… 김민재 잘 막고, 손흥민 못 넣고
# 17          제대로 열받은 콘테, 질문 1개 받고 기자회견 자리 박찼다
# 18     한국전도 부탁해! 우루과이FW, 챔스서 빈 골대 ￡85M 대폭발 슛
# 19       “아무도 몰랐던 김민재, 쿨리발리보다 강해” 伊 명장 푹 빠졌다
#
#                                                   url  \
# 0   https://sports.news.naver.com/wfootball/news/r...
# 1   https://sports.news.naver.com/wfootball/news/r...
# 2   https://sports.news.naver.com/wfootball/news/r...
# 3   https://sports.news.naver.com/wfootball/news/r...
# 4   https://sports.news.naver.com/wfootball/news/r...
# 5   https://sports.news.naver.com/wfootball/news/r...
# 6   https://sports.news.naver.com/wfootball/news/r...
# 7   https://sports.news.naver.com/wfootball/news/r...
# 8   https://sports.news.naver.com/wfootball/news/r...
# 9   https://sports.news.naver.com/wfootball/news/r...
# 10  https://sports.news.naver.com/wfootball/news/r...
# 11  https://sports.news.naver.com/wfootball/news/r...
# 12  https://sports.news.naver.com/wfootball/news/r...
# 13  https://sports.news.naver.com/wfootball/news/r...
# 14  https://sports.news.naver.com/wfootball/news/r...
# 15  https://sports.news.naver.com/wfootball/news/r...
# 16  https://sports.news.naver.com/wfootball/news/r...
# 17  https://sports.news.naver.com/wfootball/news/r...
# 18  https://sports.news.naver.com/wfootball/news/r...
# 19  https://sports.news.naver.com/wfootball/news/r...
#
#                                            short_desc  \
# 0   ▲ 안토니오 콘테 토트넘 홋스퍼 감독.[스포티비뉴스=김건일 기자] 잉글랜드 프리미어...
# 1   SC프라이부르크의 '작은' 정우영과 '황·황 듀오' 황의조와 황인범이 유로파리그에 ...
# 2   [스포탈코리아] 박주성 기자= 랄프 랑닉 감독의 말을 들었다면 어땠을까.독일 언론 ...
# 3   사진=BT 스포츠[포포투=김환]에메르송 로얄이 어이없는 노룩패스를 선보였다.토트넘 ...
# 4   [사진] ⓒGettyimages(무단전재 및 재배포 금지)[OSEN=서정환 기자] ...
# 5   뉴캐슬 유나이티드가 '핵심 미드필더' 브루노 기마랑이스에게 재계약을 건넨다.영국 '...
# 6   (베스트 일레븐)FC 바르셀로나가 지난여름 이적시장에서 거액의 투자를 했으나, UC...
# 7   ▲ 스포르팅CP전에서 퇴장 당한 안토니오 콘테 토트넘 홋스퍼 감독(왼쪽) ⓒ연합뉴스...
# 8   (엑스포츠뉴스 나승우 기자) 토트넘전 무단 조기 퇴근으로 물의를 빚었던 맨체스터 유...
# 9   [마이데일리 = 김건호 기자]안토니오 콘테(53, 토트넘) 감독이 VAR 판정에 분...
# 10  [스포탈코리아] 박주성 기자= 바르셀로나가 또 다시 무릎을 꿇었다.바르셀로나는 27...
# 11  사진=토트넘 훗스퍼 SNS[포포투=김환]토트넘 훗스퍼 팬들이 브리안 힐의 선발 기용...
# 12  가브리엘 제수스가 든든한 발언을 했다.아스널은 28일 오전 1시 45분(한국시간) ...
# 13  지난 11일부터 인도에서는 국제축구연맹(FIFA) 17세 이하 여자 월드컵이 열리고...
# 14  ▲ 김민재.[스포티비뉴스=맹봉주 기자] 불과 한 시즌도 안 돼 세리에A 최고 센터백...
# 15  [스포츠조선 김성원 기자]에메르송 로얄(토트넘)이 팬들로부터 거센 질타를 받고 있다...
# 16  나폴리의 김민재(위)가 27일(한국시간) 이탈리아 나폴리의 디에고 아르만도 마라도나...
# 17  로이터 연합뉴스[스포츠조선 김 용 기자] 질문 하나 받고 자리 박찬 콘테 감독.토트...
# 18  더 선 캡처.[스포츠조선 한동훈 기자] 우루과이 공격수 다윈 누녜스가 챔피언스리그에...
# 19  [스포탈코리아] 이현민 기자= 나폴리 간판 수비수로 자리 잡은 김민재(25)가 이탈...
#
#                                                  text  \
# 0   ▲ 안토니오 콘테 토트넘 홋스퍼 감독.\n\n\n[스포티비뉴스=김건일 기자] 잉글랜...
# 1   SC프라이부르크의 '작은' 정우영과 '황·황 듀오' 황의조와 황인범이 유로파리그에 ...
# 2   [스포탈코리아] 박주성 기자= 랄프 랑닉 감독의 말을 들었다면 어땠을까.\n\n독일...
# 3   사진=BT 스포츠\n\n\n[포포투=김환]\n\n에메르송 로얄이 어이없는 노룩패스를...
# 4   [사진] ⓒGettyimages(무단전재 및 재배포 금지)\n\n\n[OSEN=서정...
# 5   뉴캐슬 유나이티드가 '핵심 미드필더' 브루노 기마랑이스에게 재계약을 건넨다.\n\n...
# 6   (베스트 일레븐)\n\nFC 바르셀로나가 지난여름 이적시장에서 거액의 투자를 했으나...
# 7   ▲ 스포르팅CP전에서 퇴장 당한 안토니오 콘테 토트넘 홋스퍼 감독(왼쪽) ⓒ연합뉴스...
# 8   (엑스포츠뉴스 나승우 기자) 토트넘전 무단 조기 퇴근으로 물의를 빚었던 맨체스터 유...
# 9   [마이데일리 = 김건호 기자]안토니오 콘테(53, 토트넘) 감독이 VAR 판정에 분...
# 10  [스포탈코리아] 박주성 기자= 바르셀로나가 또 다시 무릎을 꿇었다.\n\n바르셀로나...
# 11  사진=토트넘 훗스퍼 SNS\n\n\n[포포투=김환]\n\n토트넘 훗스퍼 팬들이 브리...
# 12  가브리엘 제수스가 든든한 발언을 했다.\n\n아스널은 28일 오전 1시 45분(한국...
# 13  지난 11일부터 인도에서는 국제축구연맹(FIFA) 17세 이하 여자 월드컵이 열리고...
# 14  ▲ 김민재.\n\n\n[스포티비뉴스=맹봉주 기자] 불과 한 시즌도 안 돼 세리에A ...
# 15  [스포츠조선 김성원 기자]에메르송 로얄(토트넘)이 팬들로부터 거센 질타를 받고 있다...
# 16  UCL 레인저스전 풀타임 출전\n김, 완벽 수비로 5연승 이끌어\n나폴리 감독 “놀...
# 17  로이터 연합뉴스\n[스포츠조선 김 용 기자] 질문 하나 받고 자리 박찬 콘테 감독....
# 18  더 선 캡처.\n[스포츠조선 한동훈 기자] 우루과이 공격수 다윈 누녜스가 챔피언스리...
# 19  [스포탈코리아] 이현민 기자= 나폴리 간판 수비수로 자리 잡은 김민재(25)가 이탈...
#
#                                                   img publisher  \
# 0   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 1   https://imgnews.pstatic.net/image/origin/417/2...       머니S
# 2   https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 3   https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 4   https://imgnews.pstatic.net/image/origin/109/2...      OSEN
# 5   https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 6   https://imgnews.pstatic.net/image/origin/343/2...    베스트일레븐
# 7   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 8   https://imgnews.pstatic.net/image/origin/311/2...    엑스포츠뉴스
# 9   https://imgnews.pstatic.net/image/origin/117/2...     마이데일리
# 10  https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 11  https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 12  https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 13  https://imgnews.pstatic.net/image/origin/056/2...       KBS
# 14  https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 15  https://imgnews.pstatic.net/image/origin/076/2...     스포츠조선
# 16  https://imgnews.pstatic.net/image/origin/082/2...      부산일보
# 17  https://imgnews.pstatic.net/image/origin/076/2...     스포츠조선
# 18  https://imgnews.pstatic.net/image/origin/076/2...     스포츠조선
# 19  https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
#
#             datetime
# 0   2022.10.27 19:26
# 1   2022.10.27 19:24
# 2   2022.10.27 19:22
# 3   2022.10.27 19:21
# 4   2022.10.27 19:12
# 5   2022.10.27 19:11
# 6   2022.10.27 19:06
# 7   2022.10.27 19:01
# 8   2022.10.27 19:01
# 9   2022.10.27 18:46
# 10  2022.10.27 18:46
# 11  2022.10.27 18:41
# 12  2022.10.27 18:41
# 13  2022.10.27 18:39
# 14  2022.10.27 18:37
# 15  2022.10.27 18:29
# 16  2022.10.27 18:20
# 17  2022.10.27 18:15
# 18  2022.10.27 18:12
# 19  2022.10.27 18:12

# %% [markdown]
# If you think your crawling process is completed, you can close the selenium browser!

# %% [markdown]
# ####
