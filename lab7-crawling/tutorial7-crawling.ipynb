# %% [markdown]
# # Tutorial 7. Web Crawling
# - **GOAL**: scrapping news data from Naver News Sports
# - url: https://sports.news.naver.com/wfootball/news/index?isphoto=N

# %% [markdown]
# ### 1. Open Selenium webdriver browser
# This will open a new browser. **Don't close it** until the crawling process is completed!

# %%
from selenium import webdriver

# locate the driver in the current directory (containing this notebook file)!
driver = webdriver.Chrome('chromedriver.exe') # windows
# driver = webdriver.Chrome('chromedriver') # mac

driver.implicitly_wait(3) # waiting 3 seconds

# %%
# access to target url
driver.get('https://sports.news.naver.com/wfootball/news/index?isphoto=N')

# %% [markdown]
# ### 2. Find element(s) by css selector
# - The css selector value can be obtained by Chrome inspection tool (Ctrl + Shift + I).
# 1. Copy the css selector value of the targeting element
# 2. Get the elements (what is the difference between the two code lines below?

# %%
driver.find_element_by_css_selector('#_newsList > ul > li > div > a > span')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="da69d0d5-c2e5-48ff-8b99-382a4f5679e2")>

# %%
driver.find_elements_by_css_selector('#_newsList > ul > li > div > a > span')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="da69d0d5-c2e5-48ff-8b99-382a4f5679e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="384cb8da-7766-484f-a21b-55b9900b1381")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="637f54f5-57ea-4366-9f43-2479a8bbc018")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="aae3b404-8428-4947-9b6b-0db8f58ca2d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="9edf0fa2-7e5f-4fc7-bdf1-407193fe981b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="1bab5eff-c256-4edd-9898-1d835ae31067")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="8f6a6605-f147-4d0f-a7b7-dff51fd3b0f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="9c99aeb8-4084-46dd-a1f3-cc0efdba314b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="2340bf8a-bc5b-4e4f-81cb-a9b17bda32a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="77a37bf7-aa77-4918-add5-f190794549ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="19a35586-d972-4c8d-904d-743ced413c20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="a05458d5-5f10-42f8-b7c5-aa0440cd6ee6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="eeff8d3a-c614-4c86-bccf-cc5d7a7f465d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="e608c2d9-b967-44a3-8261-fa918de1188f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="c41e34e8-c3ed-4534-99fb-77d49505608b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="30ccbb85-3633-443d-9509-14de61d549d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="d0eee504-9509-4b97-b277-300c92f3b308")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="db7ca33c-4bb3-40bd-967e-1993448022df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="517e8efc-503d-4071-a032-7ed398b634d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="af8ec48f4d14d1d8bc3b9f442d314185", element="9d609c60-cff3-4663-b6bc-cb3ab81b6f7b")>]

# %% [markdown]
# ### 3. Scrapping data
# 1. Since the news webpage contains multiple news items (css selector value: `#_newsList > ul > li`), we will use `for` loop.
# 2. For each item, we can get attribute values like news title, news page url, or datetime.
# 3. The attribute values will be accumulated in lists.

# %%
# news items (objects)
elements = driver.find_elements_by_css_selector('#_newsList > ul > li')

# news attribute lists
title_list = []
url_list = []
desc_list = []
img_list = []
pub_list = []
dt_list = []

for x in elements:
    # title
    title = x.find_element_by_css_selector('div > a > span').text
    # short description
    desc = x.find_element_by_css_selector('div > p').text
    # page url
    url = x.find_element_by_css_selector('a').get_attribute("href")
    # image url
    img = x.find_element_by_css_selector('a > img').get_attribute("src")
    # publisher
    pub = x.find_element_by_css_selector('div > div > span.press').text
    # datetime
    dt = x.find_element_by_css_selector('div > div > span.time').text
    # print
    print(title)
    print(desc)
    print(url)
    print(img)
    print(pub, dt)
    print()
    # append news item values to the attribute lists
    title_list.append(title)
    url_list.append(url)
    desc_list.append(desc)
    img_list.append(img)
    pub_list.append(pub)
    dt_list.append(dt)
# Out:
# '레알 이적설' 손흥민, 이번엔 '리버풀행 가능성'까지 거론
# 손흥민이 레알 마드리드에 이어 리버풀과도 연결됐다. 위르겐 클롭 감독과 여러 차례 엮였던 만큼 새로운 가능성이 피어올랐다.글로벌 매체 '포포투'는 26일(한...
# https://sports.news.naver.com/wfootball/news/read?oid=413&aid=0000148932
# https://imgnews.pstatic.net/image/origin/413/2022/10/26/148932.jpg?type=w140
# 인터풋볼 2022.10.26 22:53
#
# "이렇게 들면 되나?" 박지성, 피카츄 돈까스 '상탈짤' 재연폭소(침착맨)
# 유튜브채널 ‘침착맨’ 출처 | 유튜브[스포츠서울 | 박효실기자] 한국 축구의 전설 박지성이 ‘침착맨’의 꾐에 빠져 피카츄 돈까스를 들고 짤을 재연해 폭소를 ...
# https://sports.news.naver.com/wfootball/news/read?oid=468&aid=0000894633
# https://imgnews.pstatic.net/image/origin/468/2022/10/26/894633.jpg?type=w140
# 스포츠서울 2022.10.26 22:50
#
# SON에게 “이 바보야!” 외친 토트넘 선수...이유는?
# [골닷컴] 김동호 기자 = 손흥민은 토트넘 훈련장에서 분위기 메이커이다.토트넘의 많은 선수들이 손흥민을 좋아하고 따른다. 백업 골키퍼 프레이저 포스터도 예외...
# https://sports.news.naver.com/wfootball/news/read?oid=216&aid=0000124578
# https://imgnews.pstatic.net/image/origin/216/2022/10/26/124578.jpg?type=w140
# 골닷컴 2022.10.26 22:48
#
# [오피셜] 텐 하흐 공식발표 "호날두 맨유 복귀…모든 건 끝났다"
# ▲ 호날두[스포티비뉴스=박대성 기자] 에릭 텐 하흐 감독이 크리스티아누 호날두(37)가 팀 훈련에 돌아왔고, 유로파리그 명단에 등록될 거로 알렸다.텐 하흐 ...
# https://imgnews.pstatic.net/image/origin/109/2022/10/26/4727852.jpg?type=w140
# OSEN 2022.10.26 21:47
#
# "아스널 거절했다"…맨유 '919억' 신입 이적 비화
# ▲ 맨체스터 유나이티드의 주축 수비수로 우뚝 선 리산드로 마르티네스.[스포티비뉴스=박건도 기자] 이적 비화가 공개됐다.영국 매체 '더부트룸'은 지난 25일(...
# https://sports.news.naver.com/wfootball/news/read?oid=477&aid=0000390388
# https://imgnews.pstatic.net/image/origin/477/2022/10/26/390388.jpg?type=w140
# 스포티비뉴스 2022.10.26 21:47
#
# 그만 좀 해라 호무새들아.. 맨유 감독 발끈 "호날두 질문 안 받아요"
# 에릭 텐하흐.로이터연합뉴스[스포츠조선 한동훈 기자] 맨체스터 유나이티드 에릭 텐하흐 감독이 '호무새(호날두+앵무새)' 기자들에게 질린 모양이다. 호무새는 앵...
# https://sports.news.naver.com/wfootball/news/read?oid=076&aid=0003931834
# https://imgnews.pstatic.net/image/origin/076/2022/10/26/3931834.jpg?type=w140
# 스포츠조선 2022.10.26 21:45
#
# [ucl.star] '임대 전전하던' 유망주, '미친 활동량'으로 첼시 엔진 됐다
# [포포투=김희준]지난 시즌까지 임대를 전전했던 코너 갤러거가 그레이엄 포터 감독 밑에서 중원의 엔진으로 거듭나고 있다.첼시는 26일 오전 1시 45분(한국시...
# https://sports.news.naver.com/wfootball/news/read?oid=411&aid=0000017549
# https://imgnews.pstatic.net/image/origin/411/2022/10/26/17549.jpg?type=w140
# 포포투 2022.10.26 21:31

# %% [markdown]
# Don't forget to scrap the entire news text data!
# - You can get it by iteratively access to `url_list` containing news page url values.
# - The css selector value can be obtained by Chrome inspection tool (Ctrl + Shift + I).

# %%
text_list = [] # main text will be collected

for url in url_list:
    driver.get(url)
    newstext = driver.find_element_by_css_selector('#newsEndContents').text
    text_list.append(newstext)

# %% [markdown]
# ### 4. Save data in CSV format
# We will use Pandas dataframe.

# %%
import pandas as pd

# dataframe can be made using multiple lists having same length
df = pd.DataFrame({'title': title_list, 
                   'url': url_list, 
                   'short_desc': desc_list, 
                   'text': text_list,
                   'img': img_list, 
                   'publisher': pub_list,
                   'datetime': dt_list,
                  })
df
# Out:
#                                             title  \
# 0               '레알 이적설' 손흥민, 이번엔 '리버풀행 가능성'까지 거론
# 1       "이렇게 들면 되나?" 박지성, 피카츄 돈까스 '상탈짤' 재연폭소(침착맨)
# 2                 SON에게 “이 바보야!” 외친 토트넘 선수...이유는?
# 3            [오피셜] 텐 하흐 공식발표 "호날두 맨유 복귀…모든 건 끝났다"
# 4      텐 하흐의 교통정리, "호날두 1군 합류, 바란 부상 이탈, 매과이어 복귀"
# 5           “호날두 입 다물어야...맨유에 없는 게 더 나아” 무단 퇴근 지적
# 6                   호날두, 유벤투스 시절 부당 급여 수령으로 검찰 조사
# 7        이강인 '인기 폭발'... "21세 재능" 라리가·EPL 클럽들이 원한다
# 8                콘테가 극찬했던 옛 제자, 토트넘으로?…"영입 경쟁 참전"
# 10  잉글리시 프리미어리그(EPL)에서 '맨체스터 시티 시대'를 알린 세르히오 아구에로....
# 11  [포포투=김희준]역대급 시즌을 보내고 있는 아스널이 '우승 굳히기'를 위해 겨울에도...
# 12  [마이데일리 = 이현호 기자] 토트넘이 챔피언스리그 16강 진출을 기원하며 홈구장에...
# 13  대전의 주세종이 26일 대전월드컵경기장에서 열린 2022 하나원큐 K리그1 승강 플...
# 14  손흥민(왼쪽). /사진=AFPBBNews=뉴스1잉글랜드 리버풀도 손흥민(30·토트넘...
# 15  [스포탈코리아] 반진혁 기자= 레알 마드리드가 제2의 네이마르로 불리는 엔드릭 영입...
# 16  [사진] ⓒGettyimages(무단전재 및 재배포 금지)[OSEN=강필주 기자] ...
# 17  ▲ 맨체스터 유나이티드의 주축 수비수로 우뚝 선 리산드로 마르티네스.[스포티비뉴스=...
# 18  에릭 텐하흐.로이터연합뉴스[스포츠조선 한동훈 기자] 맨체스터 유나이티드 에릭 텐하흐...
# 19  [포포투=김희준]지난 시즌까지 임대를 전전했던 코너 갤러거가 그레이엄 포터 감독 밑...
#
#                                                  text  \
# 0   손흥민이 레알 마드리드에 이어 리버풀과도 연결됐다. 위르겐 클롭 감독과 여러 차례 ...
# 1   유튜브채널 ‘침착맨’ 출처 | 유튜브\n\n[스포츠서울 | 박효실기자] 한국 축구의...
# 2   [골닷컴] 김동호 기자 = 손흥민은 토트넘 훈련장에서 분위기 메이커이다.\n\n토트...
# 3   ▲ 호날두\n\n\n[스포티비뉴스=박대성 기자] 에릭 텐 하흐 감독이 크리스티아누 ...
# 4   [포포투=김희준]\n\n맨체스터 유나이티드의 에릭 텐 하흐 감독이 현재 선수단의 문...
# 5   [스포탈코리아] 반진혁 기자= 크리스티아누 호날두가 입을 다물었어야 했다는 지적이다...
# 6   [골닷컴] 김동호 기자 = 크리스티아누 호날두를 비롯한 유벤투스 선수들이 2020년...
# 7   이강인(오른쪽). /사진=AFPBBNews=뉴스1\n대한민국의 미친 재능 이강인(2...
# 8   ▲ 테미 에이브러햄.\n\n\n[스포티비뉴스=김성연 기자] 팀의 핵심 공격수가 여전...
# 9   [골닷컴] 김동호 기자 = 이재성이 분데스리가 11라운드 베스트 11에 선정됐다.\...
# 10  잉글리시 프리미어리그(EPL)에서 '맨체스터 시티 시대'를 알린 세르히오 아구에로....
# 11  [포포투=김희준]\n\n역대급 시즌을 보내고 있는 아스널이 '우승 굳히기'를 위해 ...
# 12  [마이데일리 = 이현호 기자] 토트넘이 챔피언스리그 16강 진출을 기원하며 홈구장에...
# 13  K리그 승강PO 1차전서 김천에 2-1 승\n대전의 주세종이 26일 대전월드컵경기장...
# 14  손흥민(왼쪽). /사진=AFPBBNews=뉴스1\n잉글랜드 리버풀도 손흥민(30·토...
# 15  [스포탈코리아] 반진혁 기자= 레알 마드리드가 제2의 네이마르로 불리는 엔드릭 영입...
# 16  [사진] ⓒGettyimages(무단전재 및 재배포 금지)\n\n\n[OSEN=강필...
# 17  ▲ 맨체스터 유나이티드의 주축 수비수로 우뚝 선 리산드로 마르티네스.\n\n\n[스...
# 18  에릭 텐하흐.로이터연합뉴스\n[스포츠조선 한동훈 기자] 맨체스터 유나이티드 에릭 텐...
# 19  [포포투=김희준]\n\n지난 시즌까지 임대를 전전했던 코너 갤러거가 그레이엄 포터 ...
#
#                                                   img publisher  \
# 0   https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 1   https://imgnews.pstatic.net/image/origin/468/2...     스포츠서울
# 2   https://imgnews.pstatic.net/image/origin/216/2...       골닷컴
# 3   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 4   https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 5   https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 6   https://imgnews.pstatic.net/image/origin/216/2...       골닷컴
# 7   https://imgnews.pstatic.net/image/origin/108/2...      스타뉴스
# 8   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 9   https://imgnews.pstatic.net/image/origin/216/2...       골닷컴
# 10  https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 11  https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 12  https://imgnews.pstatic.net/image/origin/117/2...     마이데일리
# 13  https://imgnews.pstatic.net/image/origin/028/2...       한겨레
# 14  https://imgnews.pstatic.net/image/origin/108/2...      스타뉴스
# 15  https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 16  https://imgnews.pstatic.net/image/origin/109/2...      OSEN
# 17  https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 18  https://imgnews.pstatic.net/image/origin/076/2...     스포츠조선
# 19  https://imgnews.pstatic.net/image/origin/411/2...       포포투
#
#             datetime
# 0   2022.10.26 22:53
# 1   2022.10.26 22:50
# 2   2022.10.26 22:48
# 3   2022.10.26 22:44
# 4   2022.10.26 22:41
# 5   2022.10.26 22:40
# 6   2022.10.26 22:34
# 7   2022.10.26 22:33
# 8   2022.10.26 22:21
# 9   2022.10.26 22:17
# 10  2022.10.26 22:16
# 11  2022.10.26 22:11
# 12  2022.10.26 22:02
# 13  2022.10.26 21:57
# 14  2022.10.26 21:53
# 15  2022.10.26 21:52
# 16  2022.10.26 21:47
# 17  2022.10.26 21:47
# 18  2022.10.26 21:45
# 19  2022.10.26 21:31

# %% [markdown]
# Save the dataframe into a CSV (comma-separated values) file.
#
# Here, we will use `\t` (tab) instead of `,` (comma) since the news title or text may contain commas.

# %%
df.to_csv('news.csv', # filename
          sep='\t', # values separated by tab
          index=False, # exclude index column
          encoding='utf-8') # utf-8 encoding is widely used and makes us comfortable!

# %% [markdown]
# You can load data using `pd.read_csv()`.

# %%
pd.read_csv('news.csv', sep='\t')
# Out:
#                                             title  \
# 0               '레알 이적설' 손흥민, 이번엔 '리버풀행 가능성'까지 거론
# 1       "이렇게 들면 되나?" 박지성, 피카츄 돈까스 '상탈짤' 재연폭소(침착맨)
# 4   [포포투=김희준]맨체스터 유나이티드의 에릭 텐 하흐 감독이 현재 선수단의 문제들에 ...
# 5   [스포탈코리아] 반진혁 기자= 크리스티아누 호날두가 입을 다물었어야 했다는 지적이다...
# 6   [골닷컴] 김동호 기자 = 크리스티아누 호날두를 비롯한 유벤투스 선수들이 2020년...
# 7   이강인(오른쪽). /사진=AFPBBNews=뉴스1대한민국의 미친 재능 이강인(21·...
# 8   ▲ 테미 에이브러햄.[스포티비뉴스=김성연 기자] 팀의 핵심 공격수가 여전히 불확실한...
# 9   [골닷컴] 김동호 기자 = 이재성이 분데스리가 11라운드 베스트 11에 선정됐다.이...
# 10  잉글리시 프리미어리그(EPL)에서 '맨체스터 시티 시대'를 알린 세르히오 아구에로....
# 11  [포포투=김희준]역대급 시즌을 보내고 있는 아스널이 '우승 굳히기'를 위해 겨울에도...
# 12  [마이데일리 = 이현호 기자] 토트넘이 챔피언스리그 16강 진출을 기원하며 홈구장에...
# 13  대전의 주세종이 26일 대전월드컵경기장에서 열린 2022 하나원큐 K리그1 승강 플...
# 14  손흥민(왼쪽). /사진=AFPBBNews=뉴스1잉글랜드 리버풀도 손흥민(30·토트넘...
# 15  [스포탈코리아] 반진혁 기자= 레알 마드리드가 제2의 네이마르로 불리는 엔드릭 영입...
# 16  [사진] ⓒGettyimages(무단전재 및 재배포 금지)[OSEN=강필주 기자] ...
# 17  ▲ 맨체스터 유나이티드의 주축 수비수로 우뚝 선 리산드로 마르티네스.[스포티비뉴스=...
# 18  에릭 텐하흐.로이터연합뉴스[스포츠조선 한동훈 기자] 맨체스터 유나이티드 에릭 텐하흐...
# 19  [포포투=김희준]지난 시즌까지 임대를 전전했던 코너 갤러거가 그레이엄 포터 감독 밑...
#
#                                                  text  \
# 0   손흥민이 레알 마드리드에 이어 리버풀과도 연결됐다. 위르겐 클롭 감독과 여러 차례 ...
# 1   유튜브채널 ‘침착맨’ 출처 | 유튜브\n\n[스포츠서울 | 박효실기자] 한국 축구의...
# 2   [골닷컴] 김동호 기자 = 손흥민은 토트넘 훈련장에서 분위기 메이커이다.\n\n토트...
# 3   ▲ 호날두\n\n\n[스포티비뉴스=박대성 기자] 에릭 텐 하흐 감독이 크리스티아누 ...
# 4   [포포투=김희준]\n\n맨체스터 유나이티드의 에릭 텐 하흐 감독이 현재 선수단의 문...
# 5   [스포탈코리아] 반진혁 기자= 크리스티아누 호날두가 입을 다물었어야 했다는 지적이다...
# 6   [골닷컴] 김동호 기자 = 크리스티아누 호날두를 비롯한 유벤투스 선수들이 2020년...
# 7   이강인(오른쪽). /사진=AFPBBNews=뉴스1\n대한민국의 미친 재능 이강인(2...
# 8   ▲ 테미 에이브러햄.\n\n\n[스포티비뉴스=김성연 기자] 팀의 핵심 공격수가 여전...
# 9   [골닷컴] 김동호 기자 = 이재성이 분데스리가 11라운드 베스트 11에 선정됐다.\...
# 10  잉글리시 프리미어리그(EPL)에서 '맨체스터 시티 시대'를 알린 세르히오 아구에로....
# 11  [포포투=김희준]\n\n역대급 시즌을 보내고 있는 아스널이 '우승 굳히기'를 위해 ...
# 12  [마이데일리 = 이현호 기자] 토트넘이 챔피언스리그 16강 진출을 기원하며 홈구장에...
# 13  K리그 승강PO 1차전서 김천에 2-1 승\n대전의 주세종이 26일 대전월드컵경기장...
# 14  손흥민(왼쪽). /사진=AFPBBNews=뉴스1\n잉글랜드 리버풀도 손흥민(30·토...
# 15  [스포탈코리아] 반진혁 기자= 레알 마드리드가 제2의 네이마르로 불리는 엔드릭 영입...
# 16  [사진] ⓒGettyimages(무단전재 및 재배포 금지)\n\n\n[OSEN=강필...
# 17  ▲ 맨체스터 유나이티드의 주축 수비수로 우뚝 선 리산드로 마르티네스.\n\n\n[스...
# 18  에릭 텐하흐.로이터연합뉴스\n[스포츠조선 한동훈 기자] 맨체스터 유나이티드 에릭 텐...
# 19  [포포투=김희준]\n\n지난 시즌까지 임대를 전전했던 코너 갤러거가 그레이엄 포터 ...
#
#                                                   img publisher  \
# 0   https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 1   https://imgnews.pstatic.net/image/origin/468/2...     스포츠서울
# 2   https://imgnews.pstatic.net/image/origin/216/2...       골닷컴
# 3   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 4   https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 5   https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 6   https://imgnews.pstatic.net/image/origin/216/2...       골닷컴
# 7   https://imgnews.pstatic.net/image/origin/108/2...      스타뉴스
# 8   https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 9   https://imgnews.pstatic.net/image/origin/216/2...       골닷컴
# 10  https://imgnews.pstatic.net/image/origin/413/2...      인터풋볼
# 11  https://imgnews.pstatic.net/image/origin/411/2...       포포투
# 12  https://imgnews.pstatic.net/image/origin/117/2...     마이데일리
# 13  https://imgnews.pstatic.net/image/origin/028/2...       한겨레
# 14  https://imgnews.pstatic.net/image/origin/108/2...      스타뉴스
# 15  https://imgnews.pstatic.net/image/origin/139/2...    스포탈코리아
# 16  https://imgnews.pstatic.net/image/origin/109/2...      OSEN
# 17  https://imgnews.pstatic.net/image/origin/477/2...    스포티비뉴스
# 18  https://imgnews.pstatic.net/image/origin/076/2...     스포츠조선
# 19  https://imgnews.pstatic.net/image/origin/411/2...       포포투
#
#             datetime
# 0   2022.10.26 22:53
# 1   2022.10.26 22:50
# 2   2022.10.26 22:48
# 3   2022.10.26 22:44
# 4   2022.10.26 22:41
# 5   2022.10.26 22:40
# 6   2022.10.26 22:34
# 7   2022.10.26 22:33
# 8   2022.10.26 22:21
# 9   2022.10.26 22:17
# 10  2022.10.26 22:16
# 11  2022.10.26 22:11
# 12  2022.10.26 22:02
# 13  2022.10.26 21:57
# 14  2022.10.26 21:53
# 15  2022.10.26 21:52
# 16  2022.10.26 21:47
# 17  2022.10.26 21:47
# 18  2022.10.26 21:45
# 19  2022.10.26 21:31

# %% [markdown]
# If you think your crawling process is completed, you can close the selenium browser!
