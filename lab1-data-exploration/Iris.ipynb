# %% [markdown]
# # Data Exploration
#
# - Our data: Iris dataset

# %% [markdown]
# ### 1. Load the data

# %%
# import package
import pandas as pd

# %%
# read csv file
df = pd.read_csv('./Iris.csv')

# %%
# check if the dataframe is loaded properly
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# check column names
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# check row indices
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
# access a column (=series)
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %% [markdown]
# ### 2. Summary statistics

# %%
# Summary Statistics
df.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
# how to check the mean or the stdev of a column?
print(df['SepalLengthCm'].mean())
print("The mean of SepalLengthCm is", df['SepalLengthCm'].mean())
print("The standard deviation of SepalLengthCm is", df['SepalLengthCm'].std())
print("The median of SepalLengthCm is", df['SepalLengthCm'].median())
# Out:
# 5.843333333333335
# The mean of SepalLengthCm is 5.843333333333335
# The standard deviation of SepalLengthCm is 0.8280661279778629
# The median of SepalLengthCm is 5.8

# %%
# (advanced) check the mean of four numeric columns
for col in df.columns[1:-1]:
    print("The mean of {} is {:.2f}".format(col, df[col].mean()))
# Out:
# The mean of SepalLengthCm is 5.84
# The mean of SepalWidthCm is 3.05
# The mean of PetalLengthCm is 3.76
# The mean of PetalWidthCm is 1.20

# %% [markdown]
# ### 3. Data Visualization
# Do you have any questions about your data?
# What do you want to see in your data?

# %% [markdown]
# ##### Draw a histogram using matplotlib

# %%
# import package
import matplotlib.pyplot as plt

# histogram
plt.hist(df['PetalWidthCm'], bins=10) # number of bins: 10

# details
plt.xlabel('PetalWidth')
plt.ylabel('Frequency')
plt.title('Histogram of PetalWidthCm')
# Out:
# Text(0.5, 1.0, 'Histogram of PetalWidthCm')

# %% [markdown]
# ##### Draw a histogram using seaborn

# %%
# import package
import seaborn as sns

# histogram
sns.histplot(df['PetalWidthCm'], bins=10).set(title='Histogram of PetalWidthCm')
# Out:
# [Text(0.5, 1.0, 'Histogram of PetalWidthCm')]

# %%
# for the box plot above, we will use four numeric columns only
df_num = df.iloc[:, 1:-1] # slicing syntax
df_num
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
# boxpot
sns.boxplot(df_num).set(title='Boxplot of Iris')
# Out:
# [Text(0.5, 1.0, 'Boxplot of Iris')]

# %%
# heatmap
corr = df_num.corr()
sns.heatmap(corr, annot=True).set(title="Correlation of Iris Dataset")
# Out:
# [Text(0.5, 1.0, 'Correlation of Iris Dataset')]

# %%
# scatter plot
sns.scatterplot(x=df['SepalLengthCm'], 
                y=df['PetalLengthCm']).set(title="Scatter Plot")
# Out:
# [Text(0.5, 1.0, 'Scatter Plot')]

# %%
# scatter plot (hue added)
sns.scatterplot(x=df['SepalLengthCm'], 
                y=df['PetalLengthCm'],
                hue=df['Species']).set(title="Scatter Plot")
# Out:
# [Text(0.5, 1.0, 'Scatter Plot')]

# %%
# scattermatrix
sns.pairplot(df.iloc[:, 1:], hue='Species')
